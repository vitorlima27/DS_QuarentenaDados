# %% [markdown]
# # #Quarentenadados Alura + Data Hackers

# %% [markdown]
# Um pequeno curso de Ciência de Dados para quem está começando.
# É a #QuarentenaDados, gratuita, com inscrições até domingo! Com apoio da Alura Cursos Online,
# Caelum e DataHackers. Indique para seus colegas! https://lnkd.in/dEcZ328

# %% [markdown]
# Desafios dia 02

# %%
#Importando bibliotecas

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Lendo arquivo csv com dados atualizados na aula 01
filmes = pd.read_csv('datasets/data_filmes_processado')

# %%
filmes["generos"].str.get_dummies('|').sum().sort_values(ascending=False).plot(
    kind='bar', 
    title='Filmes por categoria',
    figsize=(8,8))
plt.show()

# %%
import seaborn as sns
sns.set_style("whitegrid")

filmes_por_genero = filmes["generos"].str.get_dummies('|').sum().sort_values(ascending=False)
plt.figure(figsize=(16,8))
sns.barplot(x=filmes_por_genero.index,
            y=filmes_por_genero.values,
            palette=sns.color_palette("BuGn_r", n_colors=len(filmes_por_genero) + 4))
plt.show()

# %%
filmes.sort_values("nota_media", ascending=False)[2450:2500]
# Out:
#       Unnamed: 0  filmeId                                             titulo  \
# 8765        8765   128620                                    Victoria (2015)
# 599          599      745             Wallace & Gromit: A Close Shave (1995)
# 5480        5480    26258                                    Topo, El (1970)
# 4795        4795     7143                           Last Samurai, The (2003)
# 5451        5451    26084                              Music Man, The (1962)
# 3016        3016     4034                                     Traffic (2000)
# 4100        4100     5876                         Quiet American, The (2002)
# 2894        2894     3871                                       Shane (1953)
# 6580        6580    55247                               Into the Wild (2007)
# 2156        2156     2871                                 Deliverance (1972)
# 7946        7946    95858                               For the Birds (2000)
# ...

# %%
def plot_filme(n):
  notas_do_filme = avaliacoes.query(f"filmeId=={n}")["nota"]
  notas_do_filme.plot(kind='hist')
  return notas_do_filme.describe()

# %%
#Mágico de Oz
plot_filme(919)
# Out:
# count    92.000000
# mean      3.880435
# std       1.025418
# min       1.000000
# 25%       3.000000
# 50%       4.000000
# 75%       5.000000
# max       5.000000
# Name: nota, dtype: float64

# %%
def plot_filme(n):
  notas_do_filme = avaliacoes.query(f"filmeId=={n}")["nota"]
  notas_do_filme.plot(kind='hist')
  plt.show()
  print('\n')
  notas_do_filme.plot.box()
  plt.show()
  return notas_do_filme.describe()

# %%
plot_filme(919)
# Out:
# count    92.000000
# mean      3.880435
# std       1.025418
# min       1.000000
# 25%       3.000000
# 50%       4.000000
# 75%       5.000000
# max       5.000000
# Name: nota, dtype: float64

# %%
sns.boxplot(data = avaliacoes.query("filmeId in [1,2,919,46578]"), x ="filmeId", y="nota")

# %% [markdown]
# # Desafio 1 do Guilherme Silveira
# Rotacionar os thicks (os nomes dos generos) do gráfico de barras verdes (o último), de forma a deixar as legendas mais legíveis.

# %%
#Mesmo gráfico, porém adicionado a rotação dos labels do eixo X
sns.set_style("whitegrid")

filmes_por_genero = filmes["generos"].str.get_dummies('|').sum().sort_values(ascending=False)
plt.figure(figsize=(16,8))
sns.barplot(x=filmes_por_genero.index,
            y=filmes_por_genero.values,
            palette=sns.color_palette("BuGn_r", n_colors=len(filmes_por_genero) + 4))

plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Desafio 2 do Paulo Silveira
# Encontar vários filmes com médias próximas e distribuições diferentes, use a função plot_filmes(n) para plotar.

# %%
#Resolvi escolher dois filmes com nota 3.90 mas com avaliações bem diferentes
#1° 4795 Last Samurai, The (2003)
plot_filme(4795)
# Out:
# count    3.000000
# mean     3.666667
# std      0.577350
# min      3.000000
# 25%      3.500000
# 50%      4.000000
# 75%      4.000000
# max      4.000000
# Name: nota, dtype: float64

# %%
#2° 745 Meet John Doe (1941)
plot_filme(745)
# Out:
# count    48.000000
# mean      3.895833
# std       1.101055
# min       1.000000
# 25%       3.500000
# 50%       4.000000
# 75%       5.000000
# max       5.000000
# Name: nota, dtype: float64

# %% [markdown]
# # Desafio 3 do Paulo Silveira
# Criar o boxplot dos 10 filmes com mais votos (não é com maior média, é com mais votos!). Não apenas plot mas também analise e tente tirar conclusões.

# %%
#Ordenei os filmes em ordem decrescente e peguei os top 10
dez_mais = filmes.sort_values(by='avaliacoes', ascending=False).head(10)
dez_mais
# Out:
#       Unnamed: 0  filmeId                                     titulo  \
# 314          314      356                        Forrest Gump (1994)
# 277          277      318           Shawshank Redemption, The (1994)
# 257          257      296                        Pulp Fiction (1994)
# 510          510      593           Silence of the Lambs, The (1991)
# 1939        1939     2571                         Matrix, The (1999)
# 224          224      260  Star Wars: Episode IV - A New Hope (1977)
# 418          418      480                       Jurassic Park (1993)
# 97            97      110                          Braveheart (1995)
# 507          507      589          Terminator 2: Judgment Day (1991)
# 461          461      527                    Schindler's List (1993)
#
#                                generos  nota_media  avaliacoes
# 314           Comedy|Drama|Romance|War        4.16       329.0
# 277                        Crime|Drama        4.43       317.0
# ...

# %%
plt.figure(figsize=(18, 8))

ax = sns.boxplot(x='filmeId', y='nota', data=avaliacoes.query(f"filmeId in {dez_mais['filmeId'].to_list()}"))
ax.set_xticklabels(dez_mais['titulo'].to_list(), fontsize=12)
ax.set_xlabel("Filme", fontsize=16)
ax.set_ylabel("Nota", fontsize=16)
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# # Desafio 4 do Guilherme Silveira
# Configurar a visualização do boxplot gerado pelo seaborn (último boxplot plotado na aula). Configurar o tamanho e colocar o nome dos filmes nos thicks.

# %%
plt.figure(figsize=(12,8))

ax = sns.boxplot(data = avaliacoes.query("filmeId in [1,2,919,46578]"), x ="filmeId", y="nota")
ax.set_xticklabels(filmes.query("filmeId in [1,2,919,46578]")['titulo'], fontsize=12)
ax.set_xlabel("Filme", fontsize=16)
ax.set_ylabel("Nota", fontsize=16)

plt.show()

# %% [markdown]
# # Desafio 5 do Allan Spadini
# Calcular moda, média e mediana dos filmes. Explore filmes com notas mais próximas de 0.5, 3 e 5.

# %%
avaliacoes = pd.read_csv("https://github.com/alura-cursos/introducao-a-data-science/blob/master/aula0/ml-latest-small/ratings.csv?raw=true")

# %%
avaliacoes.columns = ["usuarioId", "filmeId", "nota", "momento"]

# %%
avaliacoes.head()
# Out:
#    usuarioId  filmeId  nota    momento
# 0          1        1   4.0  964982703
# 1          1        3   4.0  964981247
# 2          1        6   4.0  964982224
# 3          1       47   5.0  964983815
# 4          1       50   5.0  964982931

# %%
def explora_filme(filme_id):
    filme = filmes.query(f'filmeId == {filme_id}')
    notas = avaliacoes.query(f'filmeId == {filme_id}')['nota']
    
    print(f'Filme: {filme.iloc[0, 1]}')
    print()
    
    print(f'Moda: {notas.mode().values}')    
    print(f'Média: {notas.mean()}')
    print(f'Mediana: {notas.median()}')
    print('------------')

# %%
explora_filme(8387)
explora_filme(89386)
explora_filme(3774)
# Out:
# Filme: 8387
#
# Moda: [0.5]
# Média: 0.8
# Mediana: 0.5
# ------------
# Filme: 89386
#
# Moda: [0.5]
# Média: 0.5
# Mediana: 0.5
# ------------
# Filme: 3774
#
# Moda: [0.5 1. ]
# Média: 0.75
# Mediana: 0.75
# ------------

# %% [markdown]
# # Desafio 6 da Thais André
# Plotar o boxplot e o histograma um do lado do outro (na mesma figura ou em figuras distintas, mas um do lado do outro).

# %%
pulp_fiction = avaliacoes.query('filmeId == 296')['nota']

f, axes = plt.subplots(1, 2, figsize=(16, 6))

pulp_fiction.plot(kind='hist', ax=axes[0])
pulp_fiction.plot(kind='box', ax=axes[1])

plt.show()

# %% [markdown]
# # Desafio 7 do Thiago Gonçalves
# Criar um gráfico de notas médias por ano (média geral considerando todos os filmes lançados naquele ano).

# %%
filmes_com_media_e_ano = filmes.copy()
filmes_com_media_e_ano['ano'] = filmes_com_media['titulo'].str.extract("\((\d{4})\)")
filmes_com_media_e_ano.head()
# Out:
#    Unnamed: 0  filmeId                              titulo  \
# 0           0        1                    Toy Story (1995)
# 1           1        2                      Jumanji (1995)
# 2           2        3             Grumpier Old Men (1995)
# 3           3        4            Waiting to Exhale (1995)
# 4           4        5  Father of the Bride Part II (1995)
#
#                                        generos  nota_media  avaliacoes   ano
# 0  Adventure|Animation|Children|Comedy|Fantasy        3.92       215.0  1995
# 1                   Adventure|Children|Fantasy        3.43       110.0  1995
# 2                               Comedy|Romance        3.26        52.0  1995
# 3                         Comedy|Drama|Romance        2.36         7.0  1995
# 4                                       Comedy        3.07        49.0  1995

# %%
nota_media_por_ano = filmes_com_media_e_ano.groupby('ano')['nota_media'].mean()

plt.figure(figsize=(18, 8))
nota_media_por_ano.plot()
